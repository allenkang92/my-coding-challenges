# %% [markdown]
# 제목: [문제 제목]
# 플랫폼: [백준/프로그래머스/기타]
# 난이도: [레벨/티어]
# URL: [문제 링크]
# 소요시간: [풀이 시간]
#
# [문제 설명]
# - 테이블 구조와 요구사항, 입력/출력 스펙
#
# [문제 접근]
# 1. 테이블 스키마 분석
# 2. 필요한 쿼리 문법, 조인/서브쿼리 활용
# 3. 최적화 방법(인덱스, GROUP BY, WHERE 조건 등)
#
# [시간복잡도]
# - 일반적으로 SQL은 별도 표기 대신, 쿼리 최적화나 실행 계획을 언급
#
# [공간복잡도]
# - 테이블 크기와 쿼리 임시 테이블 정도만 언급
#
# [회고]
# - 쿼리 최적화에서 겪은 문제
# - 새로 배운 SQL 함수나 문법
# - 향후 유사 문제 접근 시 주의 사항
