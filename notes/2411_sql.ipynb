# %% [markdown]
# """
# 제목: [문제 제목]
# 플랫폼: [백준/프로그래머스 등]
# 난이도: [레벨/티어]
# URL: [문제 링크]
# 소요시간: [풀이에 걸린 시간]
#
# [문제 설명]
# - 핵심 요구사항 정리
#
# [문제 접근]
# 1. 첫 번째 접근 방법
# 2. 시도한 방법들
# 3. 최종 해결 방법
#
# [시간복잡도]
# - O(n)
#
# [공간복잡도]
# - O(n)
#
# [회고]
# - 어려웠던 점
# - 새롭게 배운 점
# - 다음에 비슷한 문제를 만났을 때 활용할 점
# """
